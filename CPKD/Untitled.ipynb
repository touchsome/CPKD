# %%
# %run tools/train.py configs/defeat/defeat_r50_gflv1_r101_fpn_coco_1x.py --work-dir ./work_dirs/coconew --resume-from work_dirs/defeat_r50_gflv1_r101_fpn_coco_1x_new_new/gfl_r50_fpn_1x_coco_baseline.pth
# Out:
# 2024-03-08 01:23:21,628 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.6.13 |Anaconda, Inc.| (default, Jun  4 2021, 14:25:59) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA A30 MIG 2g.12gb
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.6.r11.6/compiler.31057947_0
# GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# PyTorch: 1.10.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
# ...
